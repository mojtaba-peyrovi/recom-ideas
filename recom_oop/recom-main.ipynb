# %%
import db_connection.ihub as ihub
import db_connection.alice as alice
import pandas as pd
import numpy as np
from scipy.stats import norm
import warnings

# %%
warnings.filterwarnings('ignore')
conn = ihub.iHub_engine('expedia').connection
conn2 = alice.alice_engine('hqlive').connection

# %%
try:
    with conn2.cursor() as cursor:
        query = """
            select
            hotel_id as Hotel_ID,
            d10_hotel_city_name as city,
            d15_hotel_name as hotel_name,
            hqlive.hotel.hotel_catg_id as stars,
            d25_hotel_location_latitude as lat,
            d26_hotel_location_longitude as lon,
            count(distinct order_id) as booking,
            sum(datediff(m139_offer_checkout_date, m138_offer_checkin_date)) * room_cnt as rns,
            round(sum(c1_selling_price),0) as gbv,
            round(sum(c1_selling_price),0) / sum(datediff(m139_offer_checkout_date, m138_offer_checkin_date)) as gbv_rns
            from bi_export.order
            left join hqlive.hotel
            on 1=1
            and bi_export.order.hotel_id = hqlive.hotel.id
            where order.hotel_id <> -1
            and datediff('2018-12-01', date(m01_order_datetime_gmt0)) < 30
            and hotel_status_id = 1
            and d22_inventory_source_code = 'HQ01'
            group by 1,2,3,4
            order by gbv desc
        """
        cursor.execute(query)
        conn.commit()
        df_from_query = pd.read_sql(query, conn2)
finally:
        conn2.close()

# %%
# dataframe:
df = pd.read_csv('C:\\Users\\mojiway\\Desktop\\recom\\recom_table_2.csv',index_col=None)

# %%
df.head()
# Out:
#    hotel_id       city                         hotel_name   stars        lat  \
# 0    242495     Boston           The Godfrey Hotel Boston  4-star  42.354662
# 1     53230  Marrakech                        La Mamounia  5-star  31.621885
# 2    311703     Nassau            Grand Hyatt At Baha Mar  4-star  25.070796
# 3      8303    Bangkok           Shangri-La Hotel Bangkok  5-star  13.720692
# 4      8519       Bali  Four Seasons Resort Bali at Sayan  5-star  -8.495717
#
#           lon  booking  rns    gbv  gbv_rns
# 0  -71.061475      107  189  27007      143
# 1   -7.997605        5   11   9068      824
# 2  -77.396624        7   36   8416      234
# 3  100.513980       10   30   8151      272
# 4  115.244937        5   18   7877      438

# %%
df['commission'] = 0.15

# %%
def get_hotel_id(url):
    response = urllib.request.urlopen(url)        
    response_text = response.read() 
    soup = BeautifulSoup(response_text)
    header = soup.find("div", {"class" : "card-header"}).extract()
    header2 = str(header)
    hotel_id = header2[header2.find(":") + 1:header2.find(")")]
    return hotel_id

# %%
hotel_link = "http://recommendation-simulation.com/hotels/242495"

# %%
get_hotel_id(hotel_link)
# Out:
# '242495'

# %%
city_input = 'Bangkok'

# %%
# data slicing based on the distribution:
def distribution_cut(col):
    mean, std = norm.fit(col)
    p0 = mean + 2 * std
    p1 = mean + std
    p2 = mean
    p3 = mean-std if std < mean else mean-0.4*std
    return p0, p1, p2, p3

# %%
def calculate_score(col_name):
    slices = distribution_cut(df[col_name])
    col_title = col_name + '_' + 'score' 
    df.loc[df[col_name] > slices[0], col_title] = 1000
    df.loc[(df[col_name] < slices[0]) & (df[col_name] > slices[1]) , col_title] = 750
    df.loc[(df[col_name] < slices[1]) & (df[col_name] > slices[2]) , col_title] = 500
    df.loc[(df[col_name] < slices[2]) & (df[col_name] > slices[3]) , col_title] = 250
    df.loc[df[col_name] < slices[3], col_title] = 100

# %%
calculate_score('gbv_rns')

# %%
df['revenue'] = df['gbv_rns'] * df['commission']

# %%
df['city_score'] = np.where(df['city']== city_input, 1, 0)

# %%
calculate_score('booking')

# %%
calculate_score('gbv')

# %%
df['total_score'] = (2*df['gbv_rns_score'] + 2*df['booking_score'] \
             + 2*df['gbv_score'] + 5*df['revenue'])*df['city_score']

# %%
df.head()
# Out:
#    hotel_id       city                         hotel_name   stars        lat  \
# 0    242495     Boston           The Godfrey Hotel Boston  4-star  42.354662
# 1     53230  Marrakech                        La Mamounia  5-star  31.621885
# 2    311703     Nassau            Grand Hyatt At Baha Mar  4-star  25.070796
# 3      8303    Bangkok           Shangri-La Hotel Bangkok  5-star  13.720692
# 4      8519       Bali  Four Seasons Resort Bali at Sayan  5-star  -8.495717
#
#           lon  booking  rns    gbv  gbv_rns  commission  gbv_rns_score  \
# 0  -71.061475      107  189  27007      143        0.15          250.0
# 1   -7.997605        5   11   9068      824        0.15         1000.0
# 2  -77.396624        7   36   8416      234        0.15          500.0
# 3  100.513980       10   30   8151      272        0.15          500.0
# 4  115.244937        5   18   7877      438        0.15         1000.0
#
#    revenue  city_score  booking_score  gbv_score  total_score
# 0    21.45           0         1000.0     1000.0          0.0
# 1   123.60           0          500.0     1000.0          0.0
# 2    35.10           0          750.0     1000.0          0.0
# 3    40.80           1         1000.0     1000.0       5204.0
# 4    65.70           0          500.0     1000.0          0.0

# %%
df = df[df['total_score'] != 0].sort_values('total_score', ascending=False)

# %%
df
# Out:
#       hotel_id     city                                         hotel_name  \
# 3         8303  Bangkok                           Shangri-La Hotel Bangkok
# 15         786  Bangkok                                Banyan Tree Bangkok
# 80        8229  Bangkok                     Novotel Bangkok on Siam Square
# 165       8070  Bangkok                  Novotel Bangkok Platinum Pratunam
# 89        3572  Bangkok                               The Landmark Bangkok
# 146      16202  Bangkok   Al Meroz Hotel Bangkok - The Leading Halal Hotel
# 520       8652  Bangkok                         Radisson Blu Plaza Bangkok
# 293        472  Bangkok                      Centara Grand at CentralWorld
# 290       8468  Bangkok                         Aloft Bangkok Sukhumvit 11
# 225       8274  Bangkok                    Grande Centre Point Ratchadamri
# 162       8455  Bangkok                                    Grand Sukhumvit
# 572       8328  Bangkok                                       Vic3 Bangkok
# 800       8258  Bangkok                                 Grand Hyatt Erawan
# 818        788  Bangkok                                 SO Sofitel Bangkok
# 843       8660  Bangkok                              The Sukhothai Bangkok
# 845      12434  Bangkok                             akyra Thonglor Bangkok
# 374         33  Bangkok                                    Pullman Hotel G
# 645       8297  Bangkok                Novotel Bangkok Ploenchit Sukhumvit
# 432        212  Bangkok                            I Residence Hotel Silom
# 633       3562  Bangkok                                    BelAire Bangkok
# 739       7635  Bangkok  Galleria Sukhumvit 10 Bangkok by Compass Hospi...
# 352       3387  Bangkok                   Tarntawan Hotel Surawong Bangkok
# 484       2665  Bangkok                               Nantra Retreat & Spa
# 984      16220  Bangkok                     Hotel Royal Bangkok China Town
# 751      18491  Bangkok                                  Nantra de Comfort
# 712        358  Bangkok          Centara Watergate Pavillion Hotel Bangkok
# 686       3558  Bangkok                     Best Western Premier Sukhumvit
# 430       8405  Bangkok                                     Mandarin Hotel
# 824      11964  Bangkok                               Amber Boutique Silom
# 824           250.0     9.75           1          250.0      250.0
# 477           250.0     7.05           1          250.0      250.0
# 1235          100.0     3.75           1          500.0      100.0
# 933           250.0    22.65           1          250.0      100.0
# 1069          250.0    15.90           1          250.0      100.0
# 1070          250.0    15.90           1          250.0      100.0
# 1082          250.0    15.45           1          250.0      100.0
# 1093          250.0    14.85           1          250.0      100.0
# 1151          250.0    12.45           1          250.0      100.0
# 1153          250.0    12.30           1          250.0      100.0
# 1194          250.0     9.90           1          250.0      100.0
# 1195          250.0     9.90           1          250.0      100.0
# 1202          250.0     9.45           1          250.0      100.0
# 1054          250.0     8.25           1          250.0      100.0
# 1248          250.0     7.05           1          250.0      100.0
# 1125          250.0     6.90           1          250.0      100.0
# 1147          250.0     6.30           1          250.0      100.0
# 1257          250.0     6.00           1          250.0      100.0
# 1261          250.0     5.40           1          250.0      100.0
# 1267          250.0     4.95           1          250.0      100.0
# 1271          100.0     4.65           1          250.0      100.0
# 1273          100.0     4.35           1          250.0      100.0
# 1277          100.0     4.05           1          250.0      100.0
# 1282          100.0     3.75           1          250.0      100.0
# 1244          100.0     3.75           1          250.0      100.0
# 1284          100.0     3.45           1          250.0      100.0
# 1287          100.0     3.00           1          250.0      100.0
# 1288          100.0     3.00           1          250.0      100.0
#
#       total_score
# 3         5204.00
# 15        4686.75
# 80        3612.50
# 165       3259.50
# 89        3113.25
# 146       2688.25
# 520       2655.25
# 293       2623.00
# 290       2603.50
# 225       2599.00
# 162       2571.25
# 572       2533.75
# 800       2155.25
# 818       2149.25
# 843       2142.50
# 845       2141.75
# 374       2096.75
# 645       2075.75
# 432       2057.00
# 633       2046.50
# 739       2045.00
# 352       2042.75
# 484       2025.50
# 984       1733.00
# 751       1718.00
# 712       1593.75
# 686       1567.50
# 430       1557.00
# 824       1548.75
# 477       1535.25
# 1235      1418.75
# 933       1313.25
# 1069      1279.50
# 1070      1279.50
# 1082      1277.25
# 1093      1274.25
# 1151      1262.25
# 1153      1261.50
# 1194      1249.50
# 1195      1249.50
# 1202      1247.25
# 1054      1241.25
# 1248      1235.25
# 1125      1234.50
# 1147      1231.50
# 1257      1230.00
# 1261      1227.00
# 1267      1224.75
# 1271       923.25
# 1273       921.75
# 1277       920.25
# 1282       918.75
# 1244       918.75
# 1284       917.25
# 1287       915.00
# 1288       915.00

# %%
df['hotel_id']
# Out:
# 3        8303
# 15        786
# 80       8229
# 165      8070
# 89       3572
# 146     16202
# 520      8652
# 293       472
# 290      8468
# 225      8274
# 162      8455
# 572      8328
# 800      8258
# 818       788
# 843      8660
# 845     12434
# 374        33
# 645      8297
# 432       212
# 633      3562
# 739      7635
# 352      3387
# 484      2665
# 984     16220
# 751     18491
# 712       358
# 686      3558
# 430      8405
# 824     11964
# 477      8341
# 1235    21846
# 933      8347
# 1069     8656
# 1070     8602
# 1082     8670
# 1093    12380
# 1151    12608
# 1153       27
# 1194    12386
# 1195     5730
# 1202    12175
# 1054       58
# 1248     2909
# 1125    14293
# 1147    17368
# 1257    21845
# 1261    20880
# 1267    13348
# 1271     7611
# 1273     8644
# 1277    12154
# 1282     3566
# 1244    21538
# 1284    27157
# 1287    17971
# 1288      417
# Name: hotel_id, dtype: int64
